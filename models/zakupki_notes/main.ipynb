# %%
from sentence_transformers import SentenceTransformer
import pandas as pd
import torch
from tqdm.auto import tqdm

# Инициализация модели
model = SentenceTransformer("cointegrated/LaBSE-en-ru")
data = pd.read_csv('properties.csv')

# %%
model.encode("Бла бла кек", convert_to_tensor=True)
# Out:
# tensor([ 0.0446, -0.0682, -0.0409, -0.0753,  0.0429,  0.0165, -0.0045,  0.0084,
#         -0.0287, -0.0308, -0.0029,  0.0120, -0.0001, -0.0449, -0.0522, -0.0396,
#          0.0120,  0.0514, -0.0210,  0.0054, -0.0348,  0.0372,  0.0366,  0.0056,
#         -0.0261,  0.0131, -0.0604, -0.0209, -0.0669, -0.0359, -0.0300, -0.0181,
#         -0.0122, -0.0468, -0.0658, -0.0530, -0.0476, -0.0185, -0.0259,  0.0039,
#          0.0617,  0.0035, -0.0574,  0.0188,  0.0474, -0.0451, -0.0518,  0.0418,
#         -0.0258,  0.0318,  0.0141, -0.0122, -0.0025, -0.0713, -0.0906,  0.0107,
#         -0.0125, -0.0051, -0.0521,  0.0126,  0.0084,  0.0346, -0.0497,  0.0085,
#         -0.0200,  0.0249,  0.0861, -0.0349, -0.0049, -0.0329, -0.0416,  0.0326,
#         -0.0437, -0.0105, -0.0297, -0.0349,  0.0132, -0.0669,  0.0706,  0.0335,
#         -0.0144,  0.0218, -0.0111, -0.0832,  0.0001,  0.0038,  0.0116, -0.0577,
#          0.0119, -0.0611,  0.0687, -0.0402, -0.0493, -0.0047,  0.0276, -0.0416,
#         -0.0502, -0.0449, -0.0250,  0.0144,  0.0454, -0.0287, -0.0316,  0.0421,
#          0.0659, -0.0484,  0.0547, -0.0215,  0.0152,  0.0014,  0.0246,  0.0190,
#         -0.0656,  0.0191, -0.0363,  0.0422,  0.0038,  0.0503,  0.0748, -0.0537,
#         -0.0341,  0.0468, -0.0303,  0.0202,  0.0089, -0.0532, -0.0236,  0.0276,
#         -0.0147,  0.0144, -0.0297, -0.0647, -0.0502,  0.0105, -0.0457,  0.0424,
#         -0.0201,  0.0293,  0.0274, -0.0451,  0.0103, -0.0317, -0.0039, -0.0453,
#         -0.0479, -0.0490,  0.0101, -0.0428,  0.0422, -0.0505,  0.0382,  0.0080,
#         -0.0229, -0.0041,  0.0427,  0.0001,  0.0024,  0.0070, -0.0147, -0.0480,
#         -0.0657, -0.0306, -0.0737, -0.0345, -0.0629, -0.0298, -0.0434,  0.0348,
#         -0.0352, -0.0348, -0.0075,  0.0294, -0.0283,  0.0059,  0.0210,  0.0309,
#         -0.0154,  0.0488, -0.0140,  0.0087,  0.0541, -0.0024, -0.0055,  0.0131,
#          0.0125, -0.0175,  0.0091, -0.0351, -0.0232, -0.0068, -0.0099,  0.0254,
#         -0.0553,  0.0323, -0.0238, -0.0136,  0.0175,  0.0113, -0.0784,  0.0357,
#         -0.0126,  0.0378,  0.0225, -0.0182,  0.0032,  0.0509, -0.0016,  0.0169,
#         -0.0362, -0.0512, -0.0031,  0.0423,  0.0035,  0.0267,  0.0134,  0.0405,
#         -0.1081,  0.0388,  0.0382, -0.0200, -0.0401, -0.0300, -0.0106, -0.0024,
#         -0.0533, -0.0012, -0.0832,  0.0214, -0.0113,  0.0287,  0.0107, -0.0218,
#         -0.0601, -0.0135, -0.0380, -0.0089,  0.0064,  0.0014, -0.0548, -0.0056,
#         -0.0232, -0.0047, -0.0001, -0.0308, -0.0863,  0.0015, -0.0110, -0.0003,
#         -0.0337, -0.0054,  0.0275, -0.0372,  0.0622, -0.0949,  0.0111, -0.0398,
#          0.0392, -0.0105, -0.0006,  0.0383, -0.0126,  0.0113,  0.0353,  0.0165],
#        device='cuda:0')

# %%
# Определение размера батча
batch_size = 128  # Этот размер можно настроить в зависимости от вашей конфигурации GPU

# Функция для разбиения списка на батчи
def batch(iterable, n=1):
    l = len(iterable)
    for ndx in range(0, l, n):
        yield iterable[ndx:min(ndx + n, l)]

# Создание списка для хранения эмбеддингов
embeddings = []
sentences = data['Название характеристики'].to_list()
# Обработка предложений пакетами
for batch_sentences in tqdm(batch(sentences, batch_size), "Encoding", total=len(sentences)//batch_size):
    batch_embeddings = model.encode(batch_sentences, convert_to_tensor=True)
    embeddings.append(batch_embeddings)

# Объединение эмбеддингов в один тензор
embeddings_tensor = torch.cat(embeddings, dim=0)
# Out:
# Encoding:   0%|          | 0/7011 [00:00<?, ?it/s]

# %%
# import pickle
# file_path = "embeddings_tensor.pkl"  # Путь к файлу для сохранения
# with open(file_path, "wb") as f:
#     pickle.dump(embeddings_tensor, f)
#

# %%
import pickle

# Path to the pickle file
file_path = "embeddings_tensor.pkl"

# Reading the data from the pickle file
with open(file_path, "rb") as f:
    embeddings_tensor = pickle.load(f)

# %%
from sqlalchemy import create_engine

database_url = "postgresql://postgres:postgres@localhost:5434/zakupki"

engine = create_engine(database_url)

# data.to_sql('products', engine, if_exists='replace', index=False)

# %%
data.columns
# Out:
# Index(['ID характеристики', 'Название характеристики',
#        'ID конечной категории Портала',
#        'Наименование конечной категории Портала',
#        'Тип значения характеристики'],
#       dtype='object')

# %%
import numpy as np
import pandas as pd

# Assuming np_vectors and data are defined as per your context
np_vectors = embeddings_tensor.cpu().numpy()

with open('properties_vectors.csv', 'w', newline='') as file:
    for i in range(len(data)):
        row = data.iloc[i]
        np_vector = np_vectors[i]

        # Find minimum non-zero value, its decimals, and format the vector accordingly
        min_non_zero = np.min(np.abs(np_vector[np.nonzero(np_vector)]))
        max_decimals = len(str(min_non_zero).split('.')[-1])
        array_str = ",".join([f"{x:.{max_decimals}f}" for x in np_vector])
        formatted_str = f"{{{array_str}}}"
        # Convert all fields to string and ensure proper escaping
        id_escaped = str(row["ID характеристики"]).replace('"', '""')

        # Join the row with proper escaping and write to file
        row_str = f'"{id_escaped}","{formatted_str}"\n'
        file.write(row_str)

# %%
df = pd.read_csv("properties_vectors.csv", delimiter=',', quotechar='"')

# %%
import psycopg2
from psycopg2.extras import execute_values
database_url = "postgresql://postgres:postgres@localhost:5434/zakupki"

conn = psycopg2.connect(database_url)
cur = conn.cursor()
cur.execute("ALTER TABLE properties add column name_vector REAL[768]")
conn.commit()
cur.close()
conn.close()

# %%
import psycopg2
from psycopg2.extras import execute_values
database_url = "postgresql://postgres:postgres@localhost:5434/zakupki"
conn = psycopg2.connect(database_url)
cur = conn.cursor()

# Создание временной таблицы
create_temp_table_query = """
CREATE TEMP TABLE IF NOT EXISTS temp_property_updates (
    id INTEGER PRIMARY KEY,
name_vector REAL[768]
);
"""
cur.execute(create_temp_table_query)


# вставка во временную таблицу
insert_into_query = """
INSERT INTO temp_property_updates (id, name_vector)
VALUES %s;
"""

def batch_insert(dataframe, batch_size=100):
    # Split the DataFrame into chunks
    chunks = (len(dataframe) - 1) // batch_size + 1
    for i in range(chunks):
        # Select the next part of the DataFrame
        batch = dataframe[i*batch_size:(i+1)*batch_size]
        # Convert each row to a tuple
        tuples = [tuple(x) for x in batch.to_numpy()]
        # Execute the batch insert
        execute_values(cur, insert_into_query, tuples)
        print(f"Batch {i+1}/{chunks} inserted.")

batch_insert(df, batch_size=1000)  # Adjust the batch size as necessary


# обновление в основной таблице
update_properties_query = """
UPDATE properties
SET name_vector = temp_property_updates.name_vector
FROM temp_property_updates
WHERE properties.id = temp_property_updates.id;
"""

cur.execute(update_properties_query)

# удаление таблицы
drop_temporary_table = """
DROP TABLE IF EXISTS temp_property_updates;
"""

cur.execute(drop_temporary_table)

# Commit the changes and close the connection
conn.commit()
cur.close()
conn.close()
# Out:
# Batch 1/898 inserted.
# Batch 2/898 inserted.
# Batch 3/898 inserted.
# Batch 4/898 inserted.
# Batch 5/898 inserted.
# Batch 6/898 inserted.
# Batch 7/898 inserted.
# Batch 8/898 inserted.
# Batch 9/898 inserted.
# Batch 10/898 inserted.
# Batch 11/898 inserted.
# Batch 12/898 inserted.
# Batch 13/898 inserted.
# Batch 14/898 inserted.
# Batch 15/898 inserted.
# Batch 16/898 inserted.
# Batch 17/898 inserted.
# Batch 18/898 inserted.
# Batch 19/898 inserted.
# Batch 20/898 inserted.
# Batch 21/898 inserted.
# Batch 22/898 inserted.
# Batch 23/898 inserted.
# Batch 24/898 inserted.
# Batch 25/898 inserted.
# Batch 26/898 inserted.
# Batch 27/898 inserted.
# Batch 28/898 inserted.
# Batch 29/898 inserted.
# Batch 30/898 inserted.
# Batch 31/898 inserted.
# Batch 32/898 inserted.
# Batch 33/898 inserted.
# Batch 34/898 inserted.
# Batch 35/898 inserted.
# Batch 36/898 inserted.
# Batch 37/898 inserted.
# Batch 38/898 inserted.
# Batch 39/898 inserted.
# Batch 40/898 inserted.
# Batch 41/898 inserted.
# Batch 42/898 inserted.
# Batch 43/898 inserted.
# Batch 44/898 inserted.
# Batch 45/898 inserted.
# Batch 46/898 inserted.
# Batch 47/898 inserted.
# Batch 48/898 inserted.
# Batch 49/898 inserted.
# Batch 50/898 inserted.
# Batch 51/898 inserted.
# Batch 52/898 inserted.
# Batch 53/898 inserted.
# Batch 54/898 inserted.
# Batch 55/898 inserted.
# Batch 56/898 inserted.
# Batch 57/898 inserted.
# Batch 58/898 inserted.
# Batch 59/898 inserted.
# Batch 60/898 inserted.
# Batch 61/898 inserted.
# Batch 62/898 inserted.
# Batch 63/898 inserted.
# Batch 64/898 inserted.
# Batch 65/898 inserted.
# Batch 66/898 inserted.
# Batch 67/898 inserted.
# Batch 68/898 inserted.
# Batch 69/898 inserted.
# Batch 70/898 inserted.
# Batch 71/898 inserted.
# Batch 72/898 inserted.
# Batch 73/898 inserted.
# Batch 74/898 inserted.
# Batch 75/898 inserted.
# Batch 76/898 inserted.
# Batch 77/898 inserted.
# Batch 78/898 inserted.
# Batch 79/898 inserted.
# Batch 80/898 inserted.
# Batch 81/898 inserted.
# Batch 82/898 inserted.
# Batch 83/898 inserted.
# Batch 84/898 inserted.
# Batch 85/898 inserted.
# Batch 86/898 inserted.
# Batch 87/898 inserted.
# Batch 88/898 inserted.
# Batch 89/898 inserted.
# Batch 90/898 inserted.
# Batch 91/898 inserted.
# Batch 92/898 inserted.
# Batch 93/898 inserted.
# Batch 94/898 inserted.
# Batch 95/898 inserted.
# Batch 96/898 inserted.
# Batch 97/898 inserted.
# Batch 98/898 inserted.
# Batch 99/898 inserted.
# Batch 100/898 inserted.
# Batch 101/898 inserted.
# Batch 102/898 inserted.
# Batch 103/898 inserted.
# Batch 104/898 inserted.
# Batch 105/898 inserted.
# Batch 106/898 inserted.
# Batch 107/898 inserted.
# Batch 108/898 inserted.
# Batch 109/898 inserted.
# Batch 110/898 inserted.
# Batch 111/898 inserted.
# Batch 112/898 inserted.
# Batch 113/898 inserted.
# Batch 114/898 inserted.
# Batch 115/898 inserted.
# Batch 116/898 inserted.
# Batch 117/898 inserted.
# Batch 118/898 inserted.
# Batch 119/898 inserted.
# Batch 120/898 inserted.
# Batch 121/898 inserted.
# Batch 122/898 inserted.
# Batch 123/898 inserted.
# Batch 124/898 inserted.
# Batch 125/898 inserted.
# Batch 126/898 inserted.
# Batch 127/898 inserted.
# Batch 128/898 inserted.
# Batch 129/898 inserted.
# Batch 130/898 inserted.
# Batch 131/898 inserted.
# Batch 132/898 inserted.
# Batch 133/898 inserted.
# Batch 134/898 inserted.
# Batch 135/898 inserted.
# Batch 136/898 inserted.
# Batch 137/898 inserted.
# Batch 138/898 inserted.
# Batch 139/898 inserted.
# Batch 140/898 inserted.
# Batch 141/898 inserted.
# Batch 142/898 inserted.
# Batch 143/898 inserted.
# Batch 144/898 inserted.
# Batch 145/898 inserted.
# Batch 146/898 inserted.
# Batch 147/898 inserted.
# Batch 148/898 inserted.
# Batch 149/898 inserted.
# Batch 150/898 inserted.
# Batch 151/898 inserted.
# Batch 152/898 inserted.
# Batch 153/898 inserted.
# Batch 154/898 inserted.
# Batch 155/898 inserted.
# Batch 156/898 inserted.
# Batch 157/898 inserted.
# Batch 158/898 inserted.
# Batch 159/898 inserted.
# Batch 160/898 inserted.
# Batch 161/898 inserted.
# Batch 162/898 inserted.
# Batch 163/898 inserted.
# Batch 164/898 inserted.
# Batch 165/898 inserted.
# Batch 166/898 inserted.
# Batch 167/898 inserted.
# Batch 168/898 inserted.
# Batch 169/898 inserted.
# Batch 170/898 inserted.
# Batch 171/898 inserted.
# Batch 172/898 inserted.
# Batch 173/898 inserted.
# Batch 174/898 inserted.
# Batch 175/898 inserted.
# Batch 176/898 inserted.
# Batch 177/898 inserted.
# Batch 178/898 inserted.
# Batch 179/898 inserted.
# Batch 180/898 inserted.
# Batch 181/898 inserted.
# Batch 182/898 inserted.
# Batch 183/898 inserted.
# Batch 184/898 inserted.
# Batch 185/898 inserted.
# Batch 186/898 inserted.
# Batch 187/898 inserted.
# Batch 188/898 inserted.
# Batch 189/898 inserted.
# Batch 190/898 inserted.
# Batch 191/898 inserted.
# Batch 192/898 inserted.
# Batch 193/898 inserted.
# Batch 194/898 inserted.
# Batch 195/898 inserted.
# Batch 196/898 inserted.
# Batch 197/898 inserted.
# Batch 198/898 inserted.
# Batch 199/898 inserted.
# Batch 200/898 inserted.
# Batch 201/898 inserted.
# Batch 202/898 inserted.
# Batch 203/898 inserted.
# Batch 204/898 inserted.
# Batch 205/898 inserted.
# Batch 206/898 inserted.
# Batch 207/898 inserted.
# Batch 208/898 inserted.
# Batch 209/898 inserted.
# Batch 210/898 inserted.
# Batch 211/898 inserted.
# Batch 212/898 inserted.
# Batch 213/898 inserted.
# Batch 214/898 inserted.
# Batch 215/898 inserted.
# Batch 216/898 inserted.
# Batch 217/898 inserted.
# Batch 218/898 inserted.
# Batch 219/898 inserted.
# Batch 220/898 inserted.
# Batch 221/898 inserted.
# Batch 222/898 inserted.
# Batch 223/898 inserted.
# Batch 224/898 inserted.
# Batch 225/898 inserted.
# Batch 226/898 inserted.
# Batch 227/898 inserted.
# Batch 228/898 inserted.
# Batch 229/898 inserted.
# Batch 230/898 inserted.
# Batch 231/898 inserted.
# Batch 232/898 inserted.
# Batch 233/898 inserted.
# Batch 234/898 inserted.
# Batch 235/898 inserted.
# Batch 236/898 inserted.
# Batch 237/898 inserted.
# Batch 238/898 inserted.
# Batch 239/898 inserted.
# Batch 240/898 inserted.
# Batch 241/898 inserted.
# Batch 242/898 inserted.
# Batch 243/898 inserted.
# Batch 244/898 inserted.
# Batch 245/898 inserted.
# Batch 246/898 inserted.
# Batch 247/898 inserted.
# Batch 248/898 inserted.
# Batch 249/898 inserted.
# Batch 250/898 inserted.
# Batch 251/898 inserted.
# Batch 252/898 inserted.
# Batch 253/898 inserted.
# Batch 254/898 inserted.
# Batch 255/898 inserted.
# Batch 256/898 inserted.
# Batch 257/898 inserted.
# Batch 258/898 inserted.
# Batch 259/898 inserted.
# Batch 260/898 inserted.
# Batch 261/898 inserted.
# Batch 262/898 inserted.
# Batch 263/898 inserted.
# Batch 264/898 inserted.
# Batch 265/898 inserted.
# Batch 266/898 inserted.
# Batch 267/898 inserted.
# Batch 268/898 inserted.
# Batch 269/898 inserted.
# Batch 270/898 inserted.
# Batch 271/898 inserted.
# Batch 272/898 inserted.
# Batch 273/898 inserted.
# Batch 274/898 inserted.
# Batch 275/898 inserted.
# Batch 276/898 inserted.
# Batch 277/898 inserted.
# Batch 278/898 inserted.
# Batch 279/898 inserted.
# Batch 280/898 inserted.
# Batch 281/898 inserted.
# Batch 282/898 inserted.
# Batch 283/898 inserted.
# Batch 284/898 inserted.
# Batch 285/898 inserted.
# Batch 286/898 inserted.
# Batch 287/898 inserted.
# Batch 288/898 inserted.
# Batch 289/898 inserted.
# Batch 290/898 inserted.
# Batch 291/898 inserted.
# Batch 292/898 inserted.
# Batch 293/898 inserted.
# Batch 294/898 inserted.
# Batch 295/898 inserted.
# Batch 296/898 inserted.
# Batch 297/898 inserted.
# Batch 298/898 inserted.
# Batch 299/898 inserted.
# Batch 300/898 inserted.
# Batch 301/898 inserted.
# Batch 302/898 inserted.
# Batch 303/898 inserted.
# Batch 304/898 inserted.
# Batch 305/898 inserted.
# Batch 306/898 inserted.
# Batch 307/898 inserted.
# Batch 308/898 inserted.
# Batch 309/898 inserted.
# Batch 310/898 inserted.
# Batch 311/898 inserted.
# Batch 312/898 inserted.
# Batch 313/898 inserted.
# Batch 314/898 inserted.
# Batch 315/898 inserted.
# Batch 316/898 inserted.
# Batch 317/898 inserted.
# Batch 318/898 inserted.
# Batch 319/898 inserted.
# Batch 320/898 inserted.
# Batch 321/898 inserted.
# Batch 322/898 inserted.
# Batch 323/898 inserted.
# Batch 324/898 inserted.
# Batch 325/898 inserted.
# Batch 326/898 inserted.
# Batch 327/898 inserted.
# Batch 328/898 inserted.
# Batch 329/898 inserted.
# Batch 330/898 inserted.
# Batch 331/898 inserted.
# Batch 332/898 inserted.
# Batch 333/898 inserted.
# Batch 334/898 inserted.
# Batch 335/898 inserted.
# Batch 336/898 inserted.
# Batch 337/898 inserted.
# Batch 338/898 inserted.
# Batch 339/898 inserted.
# Batch 340/898 inserted.
# Batch 341/898 inserted.
# Batch 342/898 inserted.
# Batch 343/898 inserted.
# Batch 344/898 inserted.
# Batch 345/898 inserted.
# Batch 346/898 inserted.
# Batch 347/898 inserted.
# Batch 348/898 inserted.
# Batch 349/898 inserted.
# Batch 350/898 inserted.
# Batch 351/898 inserted.
# Batch 352/898 inserted.
# Batch 353/898 inserted.
# Batch 354/898 inserted.
# Batch 355/898 inserted.
# Batch 356/898 inserted.
# Batch 357/898 inserted.
# Batch 358/898 inserted.
# Batch 359/898 inserted.
# Batch 360/898 inserted.
# Batch 361/898 inserted.
# Batch 362/898 inserted.
# Batch 363/898 inserted.
# Batch 364/898 inserted.
# Batch 365/898 inserted.
# Batch 366/898 inserted.
# Batch 367/898 inserted.
# Batch 368/898 inserted.
# Batch 369/898 inserted.
# Batch 370/898 inserted.
# Batch 371/898 inserted.
# Batch 372/898 inserted.
# Batch 373/898 inserted.
# Batch 374/898 inserted.
# Batch 375/898 inserted.
# Batch 376/898 inserted.
# Batch 377/898 inserted.
# Batch 378/898 inserted.
# Batch 379/898 inserted.
# Batch 380/898 inserted.
# Batch 381/898 inserted.
# Batch 382/898 inserted.
# Batch 383/898 inserted.
# Batch 384/898 inserted.
# Batch 385/898 inserted.
# Batch 386/898 inserted.
# Batch 387/898 inserted.
# Batch 388/898 inserted.
# Batch 389/898 inserted.
# Batch 390/898 inserted.
# Batch 391/898 inserted.
# Batch 392/898 inserted.
# Batch 393/898 inserted.
# Batch 394/898 inserted.
# Batch 395/898 inserted.
# Batch 396/898 inserted.
# Batch 397/898 inserted.
# Batch 398/898 inserted.
# Batch 399/898 inserted.
# Batch 400/898 inserted.
# Batch 401/898 inserted.
# Batch 402/898 inserted.
# Batch 403/898 inserted.
# Batch 404/898 inserted.
# Batch 405/898 inserted.
# Batch 406/898 inserted.
# Batch 407/898 inserted.
# Batch 408/898 inserted.
# Batch 409/898 inserted.
# Batch 410/898 inserted.
# Batch 411/898 inserted.
# Batch 412/898 inserted.
# Batch 413/898 inserted.
# Batch 414/898 inserted.
# Batch 415/898 inserted.
# Batch 416/898 inserted.
# Batch 417/898 inserted.
# Batch 418/898 inserted.
# Batch 419/898 inserted.
# Batch 420/898 inserted.
# Batch 421/898 inserted.
# Batch 422/898 inserted.
# Batch 423/898 inserted.
# Batch 424/898 inserted.
# Batch 425/898 inserted.
# Batch 426/898 inserted.
# Batch 427/898 inserted.
# Batch 428/898 inserted.
# Batch 429/898 inserted.
# Batch 430/898 inserted.
# Batch 431/898 inserted.
# Batch 432/898 inserted.
# Batch 433/898 inserted.
# Batch 434/898 inserted.
# Batch 435/898 inserted.
# Batch 436/898 inserted.
# Batch 437/898 inserted.
# Batch 438/898 inserted.
# Batch 439/898 inserted.
# Batch 440/898 inserted.
# Batch 441/898 inserted.
# Batch 442/898 inserted.
# Batch 443/898 inserted.
# Batch 444/898 inserted.
# Batch 445/898 inserted.
# Batch 446/898 inserted.
# Batch 447/898 inserted.
# Batch 448/898 inserted.
# Batch 449/898 inserted.
# Batch 450/898 inserted.
# Batch 451/898 inserted.
# Batch 452/898 inserted.
# Batch 453/898 inserted.
# Batch 454/898 inserted.
# Batch 455/898 inserted.
# Batch 456/898 inserted.
# Batch 457/898 inserted.
# Batch 458/898 inserted.
# Batch 459/898 inserted.
# Batch 460/898 inserted.
# Batch 461/898 inserted.
# Batch 462/898 inserted.
# Batch 463/898 inserted.
# Batch 464/898 inserted.
# Batch 465/898 inserted.
# Batch 466/898 inserted.
# Batch 467/898 inserted.
# Batch 468/898 inserted.
# Batch 469/898 inserted.
# Batch 470/898 inserted.
# Batch 471/898 inserted.
# Batch 472/898 inserted.
# Batch 473/898 inserted.
# Batch 474/898 inserted.
# Batch 475/898 inserted.
# Batch 476/898 inserted.
# Batch 477/898 inserted.
# Batch 478/898 inserted.
# Batch 479/898 inserted.
# Batch 480/898 inserted.
# Batch 481/898 inserted.
# Batch 482/898 inserted.
# Batch 483/898 inserted.
# Batch 484/898 inserted.
# Batch 485/898 inserted.
# Batch 486/898 inserted.
# Batch 487/898 inserted.
# Batch 488/898 inserted.
# Batch 489/898 inserted.
# Batch 490/898 inserted.
# Batch 491/898 inserted.
# Batch 492/898 inserted.
# Batch 493/898 inserted.
# Batch 494/898 inserted.
# Batch 495/898 inserted.
# Batch 496/898 inserted.
# Batch 497/898 inserted.
# Batch 498/898 inserted.
# Batch 499/898 inserted.
# Batch 500/898 inserted.
# Batch 501/898 inserted.
# Batch 502/898 inserted.
# Batch 503/898 inserted.
# Batch 504/898 inserted.
# Batch 505/898 inserted.
# Batch 506/898 inserted.
# Batch 507/898 inserted.
# Batch 508/898 inserted.
# Batch 509/898 inserted.
# Batch 510/898 inserted.
# Batch 511/898 inserted.
# Batch 512/898 inserted.
# Batch 513/898 inserted.
# Batch 514/898 inserted.
# Batch 515/898 inserted.
# Batch 516/898 inserted.
# Batch 517/898 inserted.
# Batch 518/898 inserted.
# Batch 519/898 inserted.
# Batch 520/898 inserted.
# Batch 521/898 inserted.
# Batch 522/898 inserted.
# Batch 523/898 inserted.
# Batch 524/898 inserted.
# Batch 525/898 inserted.
# Batch 526/898 inserted.
# Batch 527/898 inserted.
# Batch 528/898 inserted.
# Batch 529/898 inserted.
# Batch 530/898 inserted.
# Batch 531/898 inserted.
# Batch 532/898 inserted.
# Batch 533/898 inserted.
# Batch 534/898 inserted.
# Batch 535/898 inserted.
# Batch 536/898 inserted.
# Batch 537/898 inserted.
# Batch 538/898 inserted.
# Batch 539/898 inserted.
# Batch 540/898 inserted.
# Batch 541/898 inserted.
# Batch 542/898 inserted.
# Batch 543/898 inserted.
# Batch 544/898 inserted.
# Batch 545/898 inserted.
# Batch 546/898 inserted.
# Batch 547/898 inserted.
# Batch 548/898 inserted.
# Batch 549/898 inserted.
# Batch 550/898 inserted.
# Batch 551/898 inserted.
# Batch 552/898 inserted.
# Batch 553/898 inserted.
# Batch 554/898 inserted.
# Batch 555/898 inserted.
# Batch 556/898 inserted.
# Batch 557/898 inserted.
# Batch 558/898 inserted.
# Batch 559/898 inserted.
# Batch 560/898 inserted.
# Batch 561/898 inserted.
# Batch 562/898 inserted.
# Batch 563/898 inserted.
# Batch 564/898 inserted.
# Batch 565/898 inserted.
# Batch 566/898 inserted.
# Batch 567/898 inserted.
# Batch 568/898 inserted.
# Batch 569/898 inserted.
# Batch 570/898 inserted.
# Batch 571/898 inserted.
# Batch 572/898 inserted.
# Batch 573/898 inserted.
# Batch 574/898 inserted.
# Batch 575/898 inserted.
# Batch 576/898 inserted.
# Batch 577/898 inserted.
# Batch 578/898 inserted.
# Batch 579/898 inserted.
# Batch 580/898 inserted.
# Batch 581/898 inserted.
# Batch 582/898 inserted.
# Batch 583/898 inserted.
# Batch 584/898 inserted.
# Batch 585/898 inserted.
# Batch 586/898 inserted.
# Batch 587/898 inserted.
# Batch 588/898 inserted.
# Batch 589/898 inserted.
# Batch 590/898 inserted.
# Batch 591/898 inserted.
# Batch 592/898 inserted.
# Batch 593/898 inserted.
# Batch 594/898 inserted.
# Batch 595/898 inserted.
# Batch 596/898 inserted.
# Batch 597/898 inserted.
# Batch 598/898 inserted.
# Batch 599/898 inserted.
# Batch 600/898 inserted.
# Batch 601/898 inserted.
# Batch 602/898 inserted.
# Batch 603/898 inserted.
# Batch 604/898 inserted.
# Batch 605/898 inserted.
# Batch 606/898 inserted.
# Batch 607/898 inserted.
# Batch 608/898 inserted.
# Batch 609/898 inserted.
# Batch 610/898 inserted.
# Batch 611/898 inserted.
# Batch 612/898 inserted.
# Batch 613/898 inserted.
# Batch 614/898 inserted.
# Batch 615/898 inserted.
# Batch 616/898 inserted.
# Batch 617/898 inserted.
# Batch 618/898 inserted.
# Batch 619/898 inserted.
# Batch 620/898 inserted.
# Batch 621/898 inserted.
# Batch 622/898 inserted.
# Batch 623/898 inserted.
# Batch 624/898 inserted.
# Batch 625/898 inserted.
# Batch 626/898 inserted.
# Batch 627/898 inserted.
# Batch 628/898 inserted.
# Batch 629/898 inserted.
# Batch 630/898 inserted.
# Batch 631/898 inserted.
# Batch 632/898 inserted.
# Batch 633/898 inserted.
# Batch 634/898 inserted.
# Batch 635/898 inserted.
# Batch 636/898 inserted.
# Batch 637/898 inserted.
# Batch 638/898 inserted.
# Batch 639/898 inserted.
# Batch 640/898 inserted.
# Batch 641/898 inserted.
# Batch 642/898 inserted.
# Batch 643/898 inserted.
# Batch 644/898 inserted.
# Batch 645/898 inserted.
# Batch 646/898 inserted.
# Batch 647/898 inserted.
# Batch 648/898 inserted.
# Batch 649/898 inserted.
# Batch 650/898 inserted.
# Batch 651/898 inserted.
# Batch 652/898 inserted.
# Batch 653/898 inserted.
# Batch 654/898 inserted.
# Batch 655/898 inserted.
# Batch 656/898 inserted.
# Batch 657/898 inserted.
# Batch 658/898 inserted.
# Batch 659/898 inserted.
# Batch 660/898 inserted.
# Batch 661/898 inserted.
# Batch 662/898 inserted.
# Batch 663/898 inserted.
# Batch 664/898 inserted.
# Batch 665/898 inserted.
# Batch 666/898 inserted.
# Batch 667/898 inserted.
# Batch 668/898 inserted.
# Batch 669/898 inserted.
# Batch 670/898 inserted.
# Batch 671/898 inserted.
# Batch 672/898 inserted.
# Batch 673/898 inserted.
# Batch 674/898 inserted.
# Batch 675/898 inserted.
# Batch 676/898 inserted.
# Batch 677/898 inserted.
# Batch 678/898 inserted.
# Batch 679/898 inserted.
# Batch 680/898 inserted.
# Batch 681/898 inserted.
# Batch 682/898 inserted.
# Batch 683/898 inserted.
# Batch 684/898 inserted.
# Batch 685/898 inserted.
# Batch 686/898 inserted.
# Batch 687/898 inserted.
# Batch 688/898 inserted.
# Batch 689/898 inserted.
# Batch 690/898 inserted.
# Batch 691/898 inserted.
# Batch 692/898 inserted.
# Batch 693/898 inserted.
# Batch 694/898 inserted.
# Batch 695/898 inserted.
# Batch 696/898 inserted.
# Batch 697/898 inserted.
# Batch 698/898 inserted.
# Batch 699/898 inserted.
# Batch 700/898 inserted.
# Batch 701/898 inserted.
# Batch 702/898 inserted.
# Batch 703/898 inserted.
# Batch 704/898 inserted.
# Batch 705/898 inserted.
# Batch 706/898 inserted.
# Batch 707/898 inserted.
# Batch 708/898 inserted.
# Batch 709/898 inserted.
# Batch 710/898 inserted.
# Batch 711/898 inserted.
# Batch 712/898 inserted.
# Batch 713/898 inserted.
# Batch 714/898 inserted.
# Batch 715/898 inserted.
# Batch 716/898 inserted.
# Batch 717/898 inserted.
# Batch 718/898 inserted.
# Batch 719/898 inserted.
# Batch 720/898 inserted.
# Batch 721/898 inserted.
# Batch 722/898 inserted.
# Batch 723/898 inserted.
# Batch 724/898 inserted.
# Batch 725/898 inserted.
# Batch 726/898 inserted.
# Batch 727/898 inserted.
# Batch 728/898 inserted.
# Batch 729/898 inserted.
# Batch 730/898 inserted.
# Batch 731/898 inserted.
# Batch 732/898 inserted.
# Batch 733/898 inserted.
# Batch 734/898 inserted.
# Batch 735/898 inserted.
# Batch 736/898 inserted.
# Batch 737/898 inserted.
# Batch 738/898 inserted.
# Batch 739/898 inserted.
# Batch 740/898 inserted.
# Batch 741/898 inserted.
# Batch 742/898 inserted.
# Batch 743/898 inserted.
# Batch 744/898 inserted.
# Batch 745/898 inserted.
# Batch 746/898 inserted.
# Batch 747/898 inserted.
# Batch 748/898 inserted.
# Batch 749/898 inserted.
# Batch 750/898 inserted.
# Batch 751/898 inserted.
# Batch 752/898 inserted.
# Batch 753/898 inserted.
# Batch 754/898 inserted.
# Batch 755/898 inserted.
# Batch 756/898 inserted.
# Batch 757/898 inserted.
# Batch 758/898 inserted.
# Batch 759/898 inserted.
# Batch 760/898 inserted.
# Batch 761/898 inserted.
# Batch 762/898 inserted.
# Batch 763/898 inserted.
# Batch 764/898 inserted.
# Batch 765/898 inserted.
# Batch 766/898 inserted.
# Batch 767/898 inserted.
# Batch 768/898 inserted.
# Batch 769/898 inserted.
# Batch 770/898 inserted.
# Batch 771/898 inserted.
# Batch 772/898 inserted.
# Batch 773/898 inserted.
# Batch 774/898 inserted.
# Batch 775/898 inserted.
# Batch 776/898 inserted.
# Batch 777/898 inserted.
# Batch 778/898 inserted.
# Batch 779/898 inserted.
# Batch 780/898 inserted.
# Batch 781/898 inserted.
# Batch 782/898 inserted.
# Batch 783/898 inserted.
# Batch 784/898 inserted.
# Batch 785/898 inserted.
# Batch 786/898 inserted.
# Batch 787/898 inserted.
# Batch 788/898 inserted.
# Batch 789/898 inserted.
# Batch 790/898 inserted.
# Batch 791/898 inserted.
# Batch 792/898 inserted.
# Batch 793/898 inserted.
# Batch 794/898 inserted.
# Batch 795/898 inserted.
# Batch 796/898 inserted.
# Batch 797/898 inserted.
# Batch 798/898 inserted.
# Batch 799/898 inserted.
# Batch 800/898 inserted.
# Batch 801/898 inserted.
# Batch 802/898 inserted.
# Batch 803/898 inserted.
# Batch 804/898 inserted.
# Batch 805/898 inserted.
# Batch 806/898 inserted.
# Batch 807/898 inserted.
# Batch 808/898 inserted.
# Batch 809/898 inserted.
# Batch 810/898 inserted.
# Batch 811/898 inserted.
# Batch 812/898 inserted.
# Batch 813/898 inserted.
# Batch 814/898 inserted.
# Batch 815/898 inserted.
# Batch 816/898 inserted.
# Batch 817/898 inserted.
# Batch 818/898 inserted.
# Batch 819/898 inserted.
# Batch 820/898 inserted.
# Batch 821/898 inserted.
# Batch 822/898 inserted.
# Batch 823/898 inserted.
# Batch 824/898 inserted.
# Batch 825/898 inserted.
# Batch 826/898 inserted.
# Batch 827/898 inserted.
# Batch 828/898 inserted.
# Batch 829/898 inserted.
# Batch 830/898 inserted.
# Batch 831/898 inserted.
# Batch 832/898 inserted.
# Batch 833/898 inserted.
# Batch 834/898 inserted.
# Batch 835/898 inserted.
# Batch 836/898 inserted.
# Batch 837/898 inserted.
# Batch 838/898 inserted.
# Batch 839/898 inserted.
# Batch 840/898 inserted.
# Batch 841/898 inserted.
# Batch 842/898 inserted.
# Batch 843/898 inserted.
# Batch 844/898 inserted.
# Batch 845/898 inserted.
# Batch 846/898 inserted.
# Batch 847/898 inserted.
# Batch 848/898 inserted.
# Batch 849/898 inserted.
# Batch 850/898 inserted.
# Batch 851/898 inserted.
# Batch 852/898 inserted.
# Batch 853/898 inserted.
# Batch 854/898 inserted.
# Batch 855/898 inserted.
# Batch 856/898 inserted.
# Batch 857/898 inserted.
# Batch 858/898 inserted.
# Batch 859/898 inserted.
# Batch 860/898 inserted.
# Batch 861/898 inserted.
# Batch 862/898 inserted.
# Batch 863/898 inserted.
# Batch 864/898 inserted.
# Batch 865/898 inserted.
# Batch 866/898 inserted.
# Batch 867/898 inserted.
# Batch 868/898 inserted.
# Batch 869/898 inserted.
# Batch 870/898 inserted.
# Batch 871/898 inserted.
# Batch 872/898 inserted.
# Batch 873/898 inserted.
# Batch 874/898 inserted.
# Batch 875/898 inserted.
# Batch 876/898 inserted.
# Batch 877/898 inserted.
# Batch 878/898 inserted.
# Batch 879/898 inserted.
# Batch 880/898 inserted.
# Batch 881/898 inserted.
# Batch 882/898 inserted.
# Batch 883/898 inserted.
# Batch 884/898 inserted.
# Batch 885/898 inserted.
# Batch 886/898 inserted.
# Batch 887/898 inserted.
# Batch 888/898 inserted.
# Batch 889/898 inserted.
# Batch 890/898 inserted.
# Batch 891/898 inserted.
# Batch 892/898 inserted.
# Batch 893/898 inserted.
# Batch 894/898 inserted.
# Batch 895/898 inserted.
# Batch 896/898 inserted.
# Batch 897/898 inserted.
# Batch 898/898 inserted.

# %%
# !pip install pyarrow
clear_properties = pd.read_parquet("Характеристики_v2.parquet")
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: pyarrow in /home/viktor/anaconda3/envs/lct_zakupki/lib/python3.8/site-packages (15.0.2)
# Requirement already satisfied: numpy<2,>=1.16.6 in /home/viktor/anaconda3/envs/lct_zakupki/lib/python3.8/site-packages (from pyarrow) (1.24.4)

# %%
# IDs in df but not in clear_properties
non_existing_ids = df[~df['1696344044'].isin(clear_properties['ID характеристики'])]

# IDs that exist in both
existing_ids = df[df['1696344044'].isin(clear_properties['ID характеристики'])]

# Assuming you want to see the IDs, not the entire rows
non_existing_ids_list = non_existing_ids['1696344044'].unique()
existing_ids_list = existing_ids['1696344044'].unique()

# Returning or printing the IDs
# print("Non-existing IDs in clear_properties:", non_existing_ids_list)
# if len(existing_ids_list) > 0:
#     print("ID that exists in both:", existing_ids_list[0])
# else:
#     print("No ID exists in both DataFrames.")

# %%
# Out:
#         Unnamed: 0  1696344044
# 0                5  1696331876
# 1               64  2020573886
# 2               72  2020601973
# 3              202   247190797
# 4              203   247190795
# ...            ...         ...
# 284791      897469   153435673
# 284792      897470   153435674
# 284793      897471   153435675
# 284794      897475   153513116
# 284795      897477   153516407
#
# [284796 rows x 2 columns]

# %%
non_existing_ids_list = pd.read_csv('non_existing_ids.csv')["1696344044"]
import psycopg2
from psycopg2.extras import execute_values
database_url = "postgresql://postgres:postgres@localhost:5434/zakupki"
conn = psycopg2.connect(database_url)
cur = conn.cursor()



placeholders = ', '.join(['%s'] * len(non_existing_ids_list))
query = f"DELETE FROM properties WHERE id IN ({placeholders})"
cur.execute(query, non_existing_ids_list.astype(int).tolist())



conn.commit()
cur.close()
conn.close()

# %%
non_existing_ids_str
# Out:
# '1696331876,2020573886,2020601973,247190797,247190795,247190789,247190785,247266323,247266315,247266313,2020570545,2020567663,2020568247,2020571495,2020567603,2020567003,2020574246,2020567430,2020574147,2020574159,2020568098,2020567454,2020574167,2020571589,2020568528,2020571568,2020571549,2020568542,2020574086,2020574083,2020568578,2020574143,2020574207,2020567015,2020574228,2020567571,2020576394,2020599294,2020599298,2020574831,2020574823,